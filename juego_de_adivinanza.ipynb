# %% [markdown]
# <a href="https://colab.research.google.com/github/Leorozco1960/1785-js-herencia-polimorfismo/blob/ProyectoInicial/juego_de_adivinanza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("**********************")
print("  Adivina el numero")
print("**********************")

numero_secreto = 55
entrada_str = input("Digita un número: ")
entrada = int(entrada_str)
print("El número que digitaste: ",entrada)

if (numero_secreto == entrada):
  print("¡Acertaste!")
else:
  print("El número no corresponde.")

print("Intentalo Nuevamente o cierra el programa")
